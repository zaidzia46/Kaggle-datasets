# %%
# !pip install numpy pandas matplotlib seaborn missingno squarify

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import squarify

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"/content/Paris Olmypics total medal tally 2024 - Sheet1.csv", encoding= 'unicode_escape')
df.sample(7)
# Out:
#     Position               Country  Gold  Silver  Bronze  Total Medals
# 44        45    South Africa (RSA)     1       3       2             6
# 84        85           Qatar (QAT)     0       0       1             1
# 73        74          Panama (PAN)     0       1       1             2
# 25        26          Serbia (SRB)     3       1       1             5
# 0          1   United States (USA)    40      44      43           127
# 16        17           Kenya (KEN)     4       2       5            11
# 6          7  United Kingdom (GBR)    14      22      29            65

# %%
print(df.size)
print(df.shape)
# Out:
# 540
# (90, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Position      90 non-null     int64
#  1   Country       90 non-null     object
#  2   Gold          90 non-null     int64
#  3   Silver        90 non-null     int64
#  4   Bronze        90 non-null     int64
#  5   Total Medals  90 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 4.3+ KB

# %%
df.describe(include='all').T
# Out:
#              count unique                  top freq       mean        std  \
# Position      90.0    NaN                  NaN  NaN       45.5  26.124701
# Country         90     90  United States (USA)    1        NaN        NaN
# Gold          90.0    NaN                  NaN  NaN   3.644444   7.017332
# Silver        90.0    NaN                  NaN  NaN   3.622222   6.803135
# Bronze        90.0    NaN                  NaN  NaN   4.288889   6.638743
# Total Medals  90.0    NaN                  NaN  NaN  11.555556  19.843835
#
#               min    25%   50%    75%    max
# Position      1.0  23.25  45.5  67.75   90.0
# Country       NaN    NaN   NaN    NaN    NaN
# Gold          0.0    0.0   1.0    3.0   40.0
# Silver        0.0    0.0   1.0    3.0   44.0
# Bronze        0.0    1.0   2.0    5.0   43.0
# Total Medals  1.0    2.0   5.0    9.0  127.0

# %%
msno.matrix(df) # Data is already clean
# Out:
# <Axes: >

# %%
d1  = df[['Country', 'Total Medals']].sort_values(by='Total Medals', ascending=False).head(10)
d1
# Out:
#                 Country  Total Medals
# 0   United States (USA)           127
# 1           China (CHN)            91
# 6  United Kingdom (GBR)            65
# 4          France (FRA)            64
# 3       Australia (AUS)            53
# 2           Japan (JPN)            45
# 8           Italy (ITA)            40
# 5     Netherlands (NED)            34
# 9         Germany (GER)            33
# 7     South Korea (KOR)            32

# %%
sns.catplot(
    data=d1.sort_values(by='Total Medals'),
    kind='bar',
    x='Total Medals',
    y='Country',
    palette='viridis',

)

plt.show()

# %%
df[['Country','Gold', 'Silver', 'Bronze']] \
    .style.background_gradient(cmap='RdPu')
# Out:
# <style type="text/css">
# #T_e0b1f_row0_col1, #T_e0b1f_row0_col2, #T_e0b1f_row0_col3, #T_e0b1f_row1_col1 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_e0b1f_row1_col2 {
#   background-color: #df3898;
#   color: #f1f1f1;
# }
# #T_e0b1f_row1_col3 {
#   background-color: #eb509c;
#   color: #f1f1f1;
# }
# #T_e0b1f_row2_col1, #T_e0b1f_row6_col2 {
#   background-color: #f767a1;
#   color: #f1f1f1;
# }
# #T_e0b1f_row2_col2 {
#   background-color: #fcbfbe;
#   color: #000000;
# }
# #T_e0b1f_row2_col3 {
#   background-color: #fbb5bb;
#   color: #000000;
# }
# #T_e0b1f_row3_col1 {
#   background-color: #f87ea9;
#   color: #f1f1f1;
# }
# #T_e0b1f_row3_col2 {
#   background-color: #f986ac;
#   color: #f1f1f1;
# }
# #T_e0b1f_row3_col3 {
#   background-color: #faa0b5;
#   color: #000000;
# }
# #T_e0b1f_row4_col1 {
#   background-color: #f994b1;
#   color: #000000;
# }
# #T_e0b1f_row4_col2 {
#   background-color: #e4429a;
#   color: #f1f1f1;
# }
# #T_e0b1f_row4_col3 {
# ...
