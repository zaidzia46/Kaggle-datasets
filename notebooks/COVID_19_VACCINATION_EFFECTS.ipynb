# %%
# !pip install numpy pandas

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
dp=pd.read_excel('/content/A project report on corona vaccination side effects.xlsx')
dp.head(5)
# Out:
#    Gender  Age  eduction   occupation  area of Hyderabad   \
# 0       2    2          5           1                   2
# 1       1    2          3           3                   5
# 2       1    1          4           4                   4
# 3       1    1          3           3                   5
# 4       2    5          2           1                   5
#
#    doses of the COVID-19 vaccine   Which COVID-19 vaccine  \
# 0                               4                       2
# 1                               1                       2
# 2                               4                       1
# 3                               1                       2
# 4                               1                       1
#
#    Which COVID-19 vaccine   Feeling lazy.  Lost fear about COVID-19.  ...  \
# 0                        2              1                          4  ...
# 1                        2              4                          1  ...
# ...

# %%
# !pip install plotly

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 30 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Gender                                220 non-null    int64
#  1   Age                                   220 non-null    int64
#  2   eduction                              220 non-null    int64
#  3   occupation                            220 non-null    int64
#  4   area of Hyderabad                     220 non-null    int64
#  5   doses of the COVID-19 vaccine         220 non-null    int64
#  6   Which COVID-19 vaccine                220 non-null    int64
#  7   Which COVID-19 vaccine                220 non-null    int64
#  8   Feeling lazy.                         220 non-null    int64
#  9   Lost fear about COVID-19.             220 non-null    int64
#  10  Feeling stress & anxiety.             220 non-null    int64
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns
plt.figure (figsize=(16,6))
sns.scatterplot(data=dp)
# Out:
# <Axes: >

# %%
dp.describe().T
# Out:
#                                       count      mean       std  min  25%  \
# Gender                                220.0  1.472727  0.500394  1.0  1.0
# Age                                   220.0  2.954545  1.410245  1.0  2.0
# eduction                              220.0  2.881818  1.379774  1.0  2.0
# occupation                            220.0  3.009091  1.381518  1.0  2.0
# area of Hyderabad                     220.0  3.054545  1.467059  1.0  2.0
# doses of the COVID-19 vaccine         220.0  2.500000  1.152722  1.0  1.0
# Which COVID-19 vaccine                220.0  1.522727  0.500622  1.0  1.0
# Which COVID-19 vaccine                220.0  1.463636  0.499813  1.0  1.0
# Feeling lazy.                         220.0  2.922727  1.410473  1.0  2.0
# Lost fear about COVID-19.             220.0  2.950000  1.408471  1.0  2.0
# Feeling stress & anxiety.             220.0  3.113636  1.440065  1.0  2.0
# Hair fall.                            220.0  2.963636  1.461389  1.0  2.0
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='Gender', data=dp, palette='pastel')
plt.xticks(rotation=90)
plt.title('Number of Gender')
plt.grid(axis= 'y' , alpha= 0.75 )
plt.xticks(rotation= 90 )
plt.show()
# Out:
# <ipython-input-16-7aa922c0aa5d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=dp, palette='pastel')

# %%
corr=dp.corr()
sns.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values)
# Out:
# <Axes: >

# %%
print (dp. dtypes)
# Out:
# Gender                                  int64
# Age                                     int64
# eduction                                int64
# occupation                              int64
# area of Hyderabad                       int64
# doses of the COVID-19 vaccine           int64
# Which COVID-19 vaccine                  int64
# Which COVID-19 vaccine                  int64
# Feeling lazy.                           int64
# Lost fear about COVID-19.               int64
# Feeling stress & anxiety.               int64
# Hair fall.                              int64
# Decreasing visualization.               int64
# fear of Heart attacks.                  int64
# Overweight.                             int64
# Body pains.                             int64
# Feeling increase in immunit             int64
# Confident about the COVID-              int64
# Sleepless.                              int64
# Low & high BP.                          int64
# ...

# %%
dp.dropna(inplace=True)
dp.shape
# Out:
# (220, 30)

# %%
print(dp.columns)
# Out:
# Index(['Gender', 'Age', 'eduction ', 'occupation', 'area of Hyderabad ',
#        'doses of the COVID-19 vaccine ', 'Which COVID-19 vaccine',
#        'Which COVID-19 vaccine ', 'Feeling lazy.', 'Lost fear about COVID-19.',
#        'Feeling stress & anxiety.', 'Hair fall.', 'Decreasing visualization.',
#        'fear of Heart attacks.', 'Overweight.', 'Body pains.',
#        'Feeling increase in immunit', 'Confident about the COVID-',
#        'Sleepless.', 'Low & high BP.', 'Chills and diarrhea.',
#        'Prevented our future disea', 'Get back to our normal lif',
#        'Feeling hungry.', 'Decrease mortality rate.',
#        'Effects on reproductive he', ' Resilience.',
#        'Feel I am a part in covid 19 warrior', 'Social resposibility ',
#        'mandatory in Organization'],
#       dtype='object')

# %% [markdown]
# **About Dataset**
#
# He survey file is an Excel document that captures the effects of COVID-19 vaccination among people in Hyderabad. This file serves as a comprehensive dataset gathered through structured questionnaires to understand various aspects related to the COVID-19 vaccination, including its impact, side effects, public perception, and overall experience in the Hyderabad region.
