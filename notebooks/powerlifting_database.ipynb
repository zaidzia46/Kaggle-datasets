# %%
# !pip install pandas

# %%
import pandas as pd
reviews = pd.read_csv("/content/meets.csv", index_col=0)

# %%
reviews.head()
# Out:
#               MeetPath Federation        Date MeetCountry MeetState  \
# MeetID
# 0       365strong/1601  365Strong  2016-10-29         USA        NC
# 1       365strong/1602  365Strong  2016-11-19         USA        MO
# 2       365strong/1603  365Strong  2016-07-09         USA        NC
# 3       365strong/1604  365Strong  2016-06-11         USA        SC
# 4       365strong/1605  365Strong  2016-04-10         USA        SC
#
#          MeetTown                                           MeetName
# MeetID
# 0       Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 1           Ozark                  Thanksgiving Powerlifting Classic
# 2       Charlotte                             Charlotte Europa Games
# 3       Rock Hill                   Carolina Cup Push Pull Challenge
# 4       Rock Hill                              Eastern USA Challenge

# %%
reviews.MeetState.dtype
# Out:
# dtype('O')

# %%
reviews.dtypes
# Out:
# MeetPath       object
# Federation     object
# Date           object
# MeetCountry    object
# MeetState      object
# MeetTown       object
# MeetName       object
# dtype: object

# %%
reviews[reviews.MeetTown.isnull()]
# Out:
#              MeetPath Federation        Date MeetCountry MeetState MeetTown  \
# MeetID
# 22           apa/1001        APA  2010-11-13         USA        FL      NaN
# 23           apa/1002        APA  2010-04-17         USA       NaN      NaN
# 57           apc/1703        APC  2017-03-11         USA        FL      NaN
# 59           apf/1401        WPC  2014-11-10         USA        FL      NaN
# 61           apf/1502        APF  2015-04-15         USA        FL      NaN
# ...               ...        ...         ...         ...       ...      ...
# 7689        uspa/0276        IPL  2013-10-12      Brazil        SP      NaN
# 8441     welshpa/1701    WelshPA  2017-02-18       Wales       NaN      NaN
# 8443     wpc-rus/1501        WPC  2015-11-21      Russia       NaN      NaN
# 8462        wrpf/1713       WRPF  2017-07-01    Colombia       NaN      NaN
# 8465    wrpf-can/1701   WRPF-CAN  2017-05-13      Canada       NaN      NaN
#
# ...

# %%
reviews.MeetName.fillna("Unknown")
# Out:
# MeetID
# 0       2016 Junior & Senior National Powerlifting Cha...
# 1                       Thanksgiving Powerlifting Classic
# 2                                  Charlotte Europa Games
# 3                        Carolina Cup Push Pull Challenge
# 4                                   Eastern USA Challenge
#                               ...
# 8477                                             2015 XPC
# 8478                            2016 XPC Bench Freak Show
# 8479                                2016 XPC Elite Finals
# 8480                                  2016 XPC PRO Finals
# 8481                                      2017 XPC Finals
# Name: MeetName, Length: 8482, dtype: object

# %%
reviews.MeetCountry.replace("USA", "Pakistan")
# Out:
# MeetID
# 0       Pakistan
# 1       Pakistan
# 2       Pakistan
# 3       Pakistan
# 4       Pakistan
#           ...
# 8477    Pakistan
# 8478    Pakistan
# 8479    Pakistan
# 8480    Pakistan
# 8481    Pakistan
# Name: MeetCountry, Length: 8482, dtype: object
